# %% [markdown]
# #### Requirements:
#     Download Graphviz : https://graphviz.gitlab.io/download/
#     Add bin folder in PATH

# %%
from mglearn import plots

# %% [markdown]
# #### Linear Regression Model:

# %%
plots.plot_linear_regression_wave()
# Out:
# w[0]: 0.393906  b: -0.031804

# %% [markdown]
# #### K Nearest Neighbors Algorithm:
#     KNN algorithm for classification (Assume K = 4)
#     KNN algorithm for regression (Assume K = 6)

# %%
plots.plot_knn_classification(n_neighbors = 4)

# %%
plots.plot_knn_regression(n_neighbors = 6)

# %% [markdown]
# #### Support Vector Machine
#     SVM alanyzer (Assume gamma = 0.1 and C = 0.1)
#     SVM regularization (Assume gamma = 0.1 and C = 0.1)
# SVM regularization is used for overfitting problem

# %%
plots.plot_svm(log_C=0.1,log_gamma=0.1)

# %%
 plots.plot_linear_svc_regularization()

# %% [markdown]
# #### Linear Logistic Regression:
#     This analysis system is the base of neural network.
#     One way decision system
#     Separated into many decision layers

# %%
plots.plot_logistic_regression_graph()

# %% [markdown]
# #### Neural Network:
#     Single layer neural network
#     Two layer neural network

# %%
plots.plot_single_hidden_layer_graph()

# %%
plots.plot_two_hidden_layer_graph()

# %% [markdown]
# #### Binary Confusion Matrix:
#     Probabity

# %%
plots.plot_binary_confusion_matrix()

# %% [markdown]
# #### K Mean Algorithm:
#     Data clustering algorithm

# %%
plots.plot_kmeans_algorithm()
