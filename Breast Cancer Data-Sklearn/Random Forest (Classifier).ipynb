# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as graph

# %%
cancer = load_breast_cancer()

trainX, testX = train_test_split(cancer.data, random_state=0)
trainY, testY = train_test_split(cancer.target, random_state=0)

# %% [markdown]
# #### Default parameter for Random Forest Classifier
#     RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
clf = RandomForestClassifier()
clf.fit(trainX,trainY)

print('Training data score: {:.5f}'.format(clf.score(trainX,trainY)))
print('Testing data score: {:.5f}'.format(clf.score(testX,testY)))
# Out:
# Training data score: 1.00000
# Testing data score: 0.95105

# %%
clf = RandomForestClassifier(n_estimators=100, random_state=0)
clf.fit(trainX,trainY)

print('Training data score: {:.5f}'.format(clf.score(trainX,trainY)))
print('Testing data score: {:.5f}'.format(clf.score(testX,testY)))
# Out:
# Training data score: 1.00000
# Testing data score: 0.97203

# %% [markdown]
# #### Random Forest Nature:
#     How much (as plot representation) features use in a  Random Forest
#     This is must greater than Decision Tree

# %%
graph.plot(clf.feature_importances_)
graph.show()
